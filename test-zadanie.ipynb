# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\games\anaconda\lib\site-packages (3.0.0)
# Requirement already satisfied: jdcal in c:\games\anaconda\lib\site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in c:\games\anaconda\lib\site-packages (from openpyxl) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Считаем данные в pandas DataFrame
data = pd.read_excel('data.xlsx')

# %% [markdown]
# Взглянем на данные.

# %%
data[:12]
# Out:
#               FIO      Месяц Профессия  Разряд        Оборудование  \
# 0   Абрамов Е. Д. 2009-01-01   Уборщик       3  Пилигримовые станы
# 1   Абрамов Е. Д. 2009-02-01   Уборщик       3  Пилигримовые станы
# 2   Абрамов Е. Д. 2009-03-01   Уборщик       3  Пилигримовые станы
# 3   Абрамов Е. Д. 2009-04-01   Уборщик       3  Пилигримовые станы
# 4   Абрамов Е. Д. 2009-05-01   Уборщик       3  Пилигримовые станы
# 5   Абрамов Е. Д. 2009-06-01   Уборщик       3  Пилигримовые станы
# 6   Абрамов Е. Д. 2009-07-01   Уборщик       3  Пилигримовые станы
# 7   Абрамов Е. Д. 2009-08-01   Уборщик       3  Пилигримовые станы
# 8   Абрамов Е. Д. 2009-09-01   Уборщик       3  Пилигримовые станы
# 9   Абрамов Е. Д. 2009-10-01   Уборщик       3  Пилигримовые станы
# 10  Абрамов Е. Д. 2009-11-01   Уборщик       3  Пилигримовые станы
# 11  Абрамов Е. Д. 2009-12-01   Уборщик       3  Пилигримовые станы
#
#     Вредность (балл.)  Объем производства         Доход
# 0                  18                 580  16638.000000
# 1                  18                 790  16638.000000
# 2                  18                 820  16638.000000
# 3                  18                1200  19396.411765
# 4                  18                1250  19790.470588
# 5                  18                 950  17426.117647
# 6                  18                1400  20972.647059
# 7                  18                1180  19238.788235
# 8                  18                1080  18450.670588
# 9                  18                 780  16638.000000
# 10                 18                1020  17977.800000
# 11                 18                 810  16638.000000

# %%
data['Профессия'].value_counts()/12
# Out:
# Вальцовщик                              51.0
# Нагревальщик металла                    42.0
# Подручный вальцовщика                   30.0
# Оператор поста управления               27.0
# Уборщик                                 21.0
# Контролер качества готовой продукции     9.0
# Посадчик металла                         8.0
# Резчик горячего металла                  7.0
# Огнеупорщик                              5.0
# Name: Профессия, dtype: float64

# %%
data['Оборудование'].value_counts()/12
# Out:
# Пилигримовые станы                     59.0
# Нагревательные печи                    38.0
# Калибровочный стан                     31.0
# Прошивной стан                         31.0
# Вспомогательные помещения               9.0
# Нагревательные печи, нагрев             9.0
# Контрольно-измерительная аппаратура     9.0
# Нагревательные печи, кантовка           8.0
# Калибровочный стан, ГРП                 6.0
# Name: Оборудование, dtype: float64

# %%
data['Разряд'].value_counts()/12
# Out:
# 4    56.0
# 5    41.0
# 7    38.0
# 3    35.0
# 6    30.0
# Name: Разряд, dtype: float64

# %%
data['Вредность (балл.)'].value_counts()/12
# Out:
# 18    93.0
# 22    50.0
# 8     27.0
# 0     18.0
# 16     7.0
# 11     5.0
# Name: Вредность (балл.), dtype: float64

# %%
# После первого взгляда на данные, можно отметить, что признаки: Профессия, Разряд, Оборудование и Вредность (балл.)
# не изменяются в течении года для каждого рабочего.
# С помощью следующего кода убедимся в этом наверняка. Если у какого нибудь рабочего изменится один из признаков 
# в течении года, в соответствующий список слоаваря добавится его фамилия.
lens = {'Профессия': [],
       'Разряд': [],
       'Оборудование': [],
       'Вредность (балл.)': []
       }

for feat in list(lens.keys()):
    for i in list(data['FIO'].value_counts().index):
        if len(data.loc[data['FIO'] == i][feat].value_counts()) > 1:
            lens[feat].append(i) 
            
lens
# Out:
# {'Профессия': [], 'Разряд': [], 'Оборудование': [], 'Вредность (балл.)': []}

# %% [markdown]
# Как мы видим, первоначальная догадка оказалась верной.
#
# Теперь посмотрим на то, какие признаки влияют на доход.

# %%
# Отобразим корреляции между численными признаками, включая Доход.
corrmat = data[['Разряд', 'Вредность (балл.)','Объем производства', 'Доход']].corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat)

# %% [markdown]
# Видим, что все признаки коррелируют с доходом, и при этом почти не коррелируют между собой.
#
# Далее мы можем взглянуть на то, как категориальные признаки влияют на доход. Для этого для каждого признака, а потом для каждого значания выбранного признака возьмём среднее значение дохода. И, для наглядности, построим графики этих средних значений после сортировки.

# %%
def cat_cor(feat):
    means = []
    for cat in list(data[feat].value_counts().index):
        means.append(data[data[feat] == cat]['Доход'].mean())
    return means

prof = cat_cor('Профессия')
oborud = cat_cor('Оборудование')

fig, axes = plt.subplots(nrows=1, ncols=2)
pd.Series(sorted(prof)).plot(ax=axes[0], figsize=(10,5))
pd.Series(sorted(oborud)).plot(ax=axes[1], figsize=(10,5))

# %% [markdown]
# Графики выглядят так, как будто эти признаки, если и влияют на доход, то косвенно. Так, например, можем предположить, что "разряд" не численный признак, а категориальный и посроить для него такой же график.

# %%
raz = cat_cor('Разряд')
plt.plot(sorted(raz))

# %% [markdown]
# Мы опять убедились, что "разряд" очень сильно влияет на доход. Остановимся пока что на мысли, что "Профессия" и "Оборудование" не влияют на "доход" непосредственно.

# %% [markdown]
# Теперь, перейдём к пошаговому выявлению формулы расчёта, для этого будем по возможности исключать влияние некоторых признаков и попытаемся увидеть структуру оставшихся данных.
#
# И сразу видно, что на "доход" влияет "объём производства". Давайте взглянем на то, как он влияет на примере одного рабочего.

# %%
plt.plot(data['Доход'][:12], data['Объем производства'][:12], 'ro')
plt.grid(True)

# %% [markdown]
# "Объём производства" влияет на "доход" линейно, при пересечении порогового значения. До этого порога "Объём производства" не имеет значения. Поэтому можно исключить этот признак, оставив строки, в которых "объём производства" = 580.

# %%
data[data['Объем производства'] == 580].head(10)
# Out:
#                    FIO      Месяц                             Профессия  \
# 0        Абрамов Е. Д. 2009-01-01                               Уборщик
# 12       Абрамов Ф. М. 2009-01-01                               Уборщик
# 24      Агафонов С. И. 2009-01-01                            Вальцовщик
# 36       Аксенов Е. Н. 2009-01-01                  Нагревальщик металла
# 48   Александров А. М. 2009-01-01                               Уборщик
# 60      Алексеев Н. Н. 2009-01-01                  Нагревальщик металла
# 72       Андреев Е. А. 2009-01-01                            Вальцовщик
# 84       Андреев Ф. Д. 2009-01-01             Оператор поста управления
# 96       Антонов В. Т. 2009-01-01  Контролер качества готовой продукции
# 108      Баженов Д. И. 2009-01-01             Оператор поста управления
#
#      Разряд                         Оборудование  Вредность (балл.)  \
# 0         3                   Пилигримовые станы                 18
# 12        3                   Пилигримовые станы                 18
# 24        6                   Пилигримовые станы                 18
# 36        7                  Нагревательные печи                 22
# 48        3                   Пилигримовые станы                 18
# 60        5        Нагревательные печи, кантовка                 22
# 72        5                   Калибровочный стан                 18
# 84        5                   Калибровочный стан                  8
# 96        7  Контрольно-измерительная аппаратура                  0
# 108       5              Калибровочный стан, ГРП                  8
#
#      Объем производства    Доход
# 0                   580  16638.0
# 12                  580  16029.0
# 24                  580  22260.0
# 36                  580  26020.0
# 48                  580  15420.0
# 60                  580  20350.0
# 72                  580  20449.5
# 84                  580  18649.5
# 96                  580  22060.0
# 108                 580  18649.5

# %% [markdown]
# Следующим шагом можем исключить признак "Профессия", выбрав одну профессию и выводить таблицу рабочих только этой профессии. Взглянув на строки с рабочими с одинаковой профессии я обнаружил, что профессий "Уборщик" обладают рабочие с разным "баллом вредности".

# %%
data[data['Объем производства'] == 580]\
    [data['Профессия'] == "Уборщик"]
# Out:
# C:\Games\ANACONDA\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                     FIO      Месяц Профессия  Разряд  \
# 0         Абрамов Е. Д. 2009-01-01   Уборщик       3
# 12        Абрамов Ф. М. 2009-01-01   Уборщик       3
# 48    Александров А. М. 2009-01-01   Уборщик       3
# 384       Воронов Р. И. 2009-01-01   Уборщик       3
# 468     Григорьев А. Т. 2009-01-01   Уборщик       3
# 612      Журавлев Б. И. 2009-01-01   Уборщик       3
# 792         Клюев Д. М. 2009-01-01   Уборщик       3
# 864       Комаров А. И. 2009-01-01   Уборщик       3
# 912    Кондратьев Д. Д. 2009-01-01   Уборщик       3
# 984       Краснов И. М. 2009-01-01   Уборщик       3
# 1212        Львов А. С. 2009-01-01   Уборщик       3
# 1368       Наумов О. В. 2009-01-01   Уборщик       3
# 1560       Осипов М. В. 2009-01-01   Уборщик       3
# 1596   Павловский Д. А. 2009-01-01   Уборщик       3
# 1680      Потапов М. И. 2009-01-01   Уборщик       3
# 1716     Румянцев И. Д. 2009-01-01   Уборщик       3
# 1752     Самсонов К. Д. 2009-01-01   Уборщик       3
# 1980      Сорокин М. А. 2009-01-01   Уборщик       3
# 2004     Степанов А. М. 2009-01-01   Уборщик       3
# 2148      Федотов М. М. 2009-01-01   Уборщик       3
# 2292     Чернышев Д. В. 2009-01-01   Уборщик       3
#
#                    Оборудование  Вредность (балл.)  Объем производства  \
# 0            Пилигримовые станы                 18                 580
# 12           Пилигримовые станы                 18                 580
# 48           Пилигримовые станы                 18                 580
# 384          Пилигримовые станы                 18                 580
# 468   Вспомогательные помещения                  0                 580
# 612   Вспомогательные помещения                  0                 580
# 792   Вспомогательные помещения                  0                 580
# 864          Пилигримовые станы                 18                 580
# 912   Вспомогательные помещения                  0                 580
# 984          Пилигримовые станы                 18                 580
# 1212  Вспомогательные помещения                  0                 580
# 1368  Вспомогательные помещения                  0                 580
# 1560         Пилигримовые станы                 18                 580
# 1596         Пилигримовые станы                 18                 580
# 1680         Пилигримовые станы                 18                 580
# 1716         Пилигримовые станы                 18                 580
# 1752         Пилигримовые станы                 18                 580
# 1980         Пилигримовые станы                 18                 580
# 2004  Вспомогательные помещения                  0                 580
# 2148  Вспомогательные помещения                  0                 580
# 2292  Вспомогательные помещения                  0                 580
#
#         Доход
# 0     16638.0
# 12    16029.0
# 48    15420.0
# 384   15420.0
# 468   12180.0
# 612   12180.0
# 792   12180.0
# 864   15420.0
# 912   12789.0
# 984   15420.0
# 1212  12180.0
# 1368  12180.0
# 1560  15420.0
# 1596  16029.0
# 1680  15420.0
# 1716  15420.0
# 1752  15420.0
# 1980  15420.0
# 2004  12789.0
# 2148  13398.0
# 2292  12180.0

# %% [markdown]
# Можно сделать первоначальный вывод об окладе. Минимальный "доход" уборщика как раз и будет окладом - 12180.
#
# В показанной выше таблице есть уборщики с абсолютно одинаковыми признаками, но разным доходом. И тут мы с лёгкостью можем определить, что эта разница равняется 5% и 10%. (Достаточно взглянуть на строки рабочих: Степанов А. М., Федотов М. М., Чернышев Д. В.)

# %%
data.loc[[2004, 2148, 2292]]
# Out:
#                  FIO      Месяц Профессия  Разряд               Оборудование  \
# 2004  Степанов А. М. 2009-01-01   Уборщик       3  Вспомогательные помещения
# 2148   Федотов М. М. 2009-01-01   Уборщик       3  Вспомогательные помещения
# 2292  Чернышев Д. В. 2009-01-01   Уборщик       3  Вспомогательные помещения
#
#       Вредность (балл.)  Объем производства    Доход
# 2004                  0                 580  12789.0
# 2148                  0                 580  13398.0
# 2292                  0                 580  12180.0

# %% [markdown]
# Значит доходом без индивидуальных надбавок для строк с одинаковым набором признаков будет минимальное значение дохода в подвыборке.

# %% [markdown]
# Таким же образом мы можем определить, что минимальный доход для уборщиков с баллом вредности, равным 18, это 15420.

# %%
data.loc[[0, 12, 48]]
# Out:
#                   FIO      Месяц Профессия  Разряд        Оборудование  \
# 0       Абрамов Е. Д. 2009-01-01   Уборщик       3  Пилигримовые станы
# 12      Абрамов Ф. М. 2009-01-01   Уборщик       3  Пилигримовые станы
# 48  Александров А. М. 2009-01-01   Уборщик       3  Пилигримовые станы
#
#     Вредность (балл.)  Объем производства    Доход
# 0                  18                 580  16638.0
# 12                 18                 580  16029.0
# 48                 18                 580  15420.0

# %% [markdown]
# Таблица приведённая выше доказывает предположение о индивидуальных надбавах. Но при это ещё и подчёркивает, что балл вредности не влияет на эти надбавки, они равны 5% и 10% от 12180, то есть, оклада.

# %% [markdown]
# Далее, сравнив минимальный доход для уборщиков с баллом вредности, равным 18, это 15420, и минимальный доход для уборщиков с баллом вредности, равным 0, это 12180, можем предположить, что каждый балл вредности добавляет 180 к доходу. (15420 - 12180 = 3240 = 180 * 18). Формула влияния балла вредности на "доход" данным образом подтверждается и для других профессий.

# %% [markdown]
# Теперь взглянем на профессию "Вальцовщик". (строки с "объёмом производства" равным 580).

# %%
data[data['Объем производства'] == 580]\
    [data['Профессия'] == "Вальцовщик"].head()
# Out:
# C:\Games\ANACONDA\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                 FIO      Месяц   Профессия  Разряд        Оборудование  \
# 24   Агафонов С. И. 2009-01-01  Вальцовщик       6  Пилигримовые станы
# 72    Андреев Е. А. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 120    Белкин В. И. 2009-01-01  Вальцовщик       7  Пилигримовые станы
# 168  Белоусов М. Д. 2009-01-01  Вальцовщик       6  Пилигримовые станы
# 192  Богданов А. Т. 2009-01-01  Вальцовщик       7      Прошивной стан
#
#      Вредность (балл.)  Объем производства    Доход
# 24                  18                 580  22260.0
# 72                  18                 580  20449.5
# 120                 18                 580  25300.0
# 168                 18                 580  23211.0
# 192                 18                 580  26403.0

# %% [markdown]
# Видим, что "вальцовщики" имеют разряды 5, 6 и 7. Это подтверждает теорию, что признак "профессия" сам по себе не влияет на "доход", но влияет разряд.

# %%
data[data['Объем производства'] == 580]\
    [data['Профессия'] == "Вальцовщик"]\
    [data['Разряд'] == 5]
# Out:
# C:\Games\ANACONDA\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Games\ANACONDA\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                   FIO      Месяц   Профессия  Разряд        Оборудование  \
# 72      Андреев Е. А. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 288   Винокуров М. Т. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 1020   Кузнецов Д. М. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 1032   Кузнецов О. А. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 1308   Михайлов С. М. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 1644    Поляков Д. А. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 1944   Соловьев В. М. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 2040  Терентьев М. Д. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 2088  Третьяков В. А. 2009-01-01  Вальцовщик       5  Калибровочный стан
# 2364   Щербаков А. М. 2009-01-01  Вальцовщик       5  Калибровочный стан
#
#       Вредность (балл.)  Объем производства    Доход
# 72                   18                 580  20449.5
# 288                  18                 580  20449.5
# 1020                 18                 580  20449.5
# 1032                 18                 580  19630.0
# 1308                 18                 580  19630.0
# 1644                 18                 580  20449.5
# 1944                 18                 580  19630.0
# 2040                 18                 580  19630.0
# 2088                 18                 580  20449.5
# 2364                 18                 580  19630.0

# %% [markdown]
# Можем сделать вывод, что индивидуальные надбавки для 5 разряда составляют 5% от минимального оклада среди вальцовщиков этого разряда (с поправкой на "балл вредности" 16390 = 19630 - 180 * 18). И это наводит на мысль, что окалды для кадого разряда разные и строго определённые.
#
# Взглянув на полную таблицу вальцовщиков (с объёмом производства, равным 580), явно видно, что оклад для 5 разряда равен 16390, для 6 - 19020, для 7 - 22060. С помощью таблиц для рабочих с другими разрядами я определил оклады для каждого из них.
# В итоге имеем оклады:

# %% [markdown]
# ![image.png](attachment:a900b350-ea7b-45d2-84cc-94ca21329f6e.png)

# %% [markdown]
# У меня есть два предположения, по поводу того, как образуется оклад: Либо оклад жёстко установлен для каждого разряда работодателем, либо он образуется по некой формуле.
#
# Давайте, ради интереса, попробуем получить эту формулу. "Ради интереса" - потому, что это явно не линейная функия, и мне слабо верится, что на предприятиях используют сложные формулы, приводящие к некрасивым и неудобным вычислениям и числам.
#
# Построив график зависимости оклада от разряда, становится понятно, что функция не линейная, а скорее квадратичная. Применив полиномиальную аппроксимацию второй степени, видно, что полученная кривая очень точно ложится на график.

# %% [markdown]
# ![image.png](attachment:fe8b264a-57bf-468f-b976-180e9a1a5a56.png)

# %% [markdown]
# В итоге, оклад равен 182.14*x**2 + 643.57*x + 8620.3, где x - разряд

# %% [markdown]
# Осталось выявить влияние "Объёма производства" на "доход". Для этого вернёмся к ранее построенному графику.

# %%
# Уборщик без индивидуальных надбавок и доплат за вредность
data[468:480]
# Out:
#                  FIO      Месяц Профессия  Разряд               Оборудование  \
# 468  Григорьев А. Т. 2009-01-01   Уборщик       3  Вспомогательные помещения
# 469  Григорьев А. Т. 2009-02-01   Уборщик       3  Вспомогательные помещения
# 470  Григорьев А. Т. 2009-03-01   Уборщик       3  Вспомогательные помещения
# 471  Григорьев А. Т. 2009-04-01   Уборщик       3  Вспомогательные помещения
# 472  Григорьев А. Т. 2009-05-01   Уборщик       3  Вспомогательные помещения
# 473  Григорьев А. Т. 2009-06-01   Уборщик       3  Вспомогательные помещения
# 474  Григорьев А. Т. 2009-07-01   Уборщик       3  Вспомогательные помещения
# 475  Григорьев А. Т. 2009-08-01   Уборщик       3  Вспомогательные помещения
# 476  Григорьев А. Т. 2009-09-01   Уборщик       3  Вспомогательные помещения
# 477  Григорьев А. Т. 2009-10-01   Уборщик       3  Вспомогательные помещения
# 478  Григорьев А. Т. 2009-11-01   Уборщик       3  Вспомогательные помещения
# 479  Григорьев А. Т. 2009-12-01   Уборщик       3  Вспомогательные помещения
#
#      Вредность (балл.)  Объем производства         Доход
# 468                  0                 580  12180.000000
# 469                  0                 790  12180.000000
# 470                  0                 820  12180.000000
# 471                  0                1200  14687.647059
# 472                  0                1250  15045.882353
# 473                  0                 950  12896.470588
# 474                  0                1400  16120.588235
# 475                  0                1180  14544.352941
# 476                  0                1080  13827.882353
# 477                  0                 780  12180.000000
# 478                  0                1020  13398.000000
# 479                  0                 810  12180.000000

# %%
# Уборщик с индивидуальными надбавками и доплатами за вредность

data[:12]
# Out:
#               FIO      Месяц Профессия  Разряд        Оборудование  \
# 0   Абрамов Е. Д. 2009-01-01   Уборщик       3  Пилигримовые станы
# 1   Абрамов Е. Д. 2009-02-01   Уборщик       3  Пилигримовые станы
# 2   Абрамов Е. Д. 2009-03-01   Уборщик       3  Пилигримовые станы
# 3   Абрамов Е. Д. 2009-04-01   Уборщик       3  Пилигримовые станы
# 4   Абрамов Е. Д. 2009-05-01   Уборщик       3  Пилигримовые станы
# 5   Абрамов Е. Д. 2009-06-01   Уборщик       3  Пилигримовые станы
# 6   Абрамов Е. Д. 2009-07-01   Уборщик       3  Пилигримовые станы
# 7   Абрамов Е. Д. 2009-08-01   Уборщик       3  Пилигримовые станы
# 8   Абрамов Е. Д. 2009-09-01   Уборщик       3  Пилигримовые станы
# 9   Абрамов Е. Д. 2009-10-01   Уборщик       3  Пилигримовые станы
# 10  Абрамов Е. Д. 2009-11-01   Уборщик       3  Пилигримовые станы
# 11  Абрамов Е. Д. 2009-12-01   Уборщик       3  Пилигримовые станы
#
#     Вредность (балл.)  Объем производства         Доход
# 0                  18                 580  16638.000000
# 1                  18                 790  16638.000000
# 2                  18                 820  16638.000000
# 3                  18                1200  19396.411765
# 4                  18                1250  19790.470588
# 5                  18                 950  17426.117647
# 6                  18                1400  20972.647059
# 7                  18                1180  19238.788235
# 8                  18                1080  18450.670588
# 9                  18                 780  16638.000000
# 10                 18                1020  17977.800000
# 11                 18                 810  16638.000000

# %%
plt.plot( data['Объем производства'][468:480], data['Доход'][468:480], 'ro')
plt.grid(True)

# %% [markdown]
# Нам необходимо узнать значение порога "Объёма производства" и коэффициент прямой. Мы уже имеем представление об итоговой формуле, поэтому для рассчёта двух неизвестных нам нужно решить систему из двух уравнений для двух рзных точек, принадлежащих прямой.

# %% [markdown]
# (1) ![image.png](attachment:47f0265e-472c-46e3-a7a8-fff76a7bbecc.png)

# %% [markdown]
# (2) ![image.png](attachment:1caeb211-e8ad-4dd4-b0fb-48e5ae9f59af.png)

# %% [markdown]
# Приравняв формулы для К с разными "доходами" и "объёмами" вычисляем "Начальный объём" - 850.
# После чего подставим его в формулу (2) и получим К = 7,165

# %% [markdown]
# В итоге, премия рассчитывается следующим образом:

# %% [markdown]
# ![image.png](attachment:de5e114b-74e4-4cc4-991d-5420187cc704.png)

# %% [markdown]
# Ответ:

# %% [markdown]
# ![image.png](attachment:image.png)
